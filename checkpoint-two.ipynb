# %% [markdown]
# # Checkpoint Two: Exploratory Data Analysis
#
# Now that your chosen dataset is approved, it is time to start working on your analysis. Use this notebook to perform your EDA and make notes where directed to as you work.
#
# ## Getting Started
#
# Since we have not provided your dataset for you, you will need to load the necessary files in this repository. Make sure to include a link back to the original dataset here as well.
#
# My dataset:https://www.kaggle.com/datasets/andreuvallhernndez/myanimelist
#
# Your first task in EDA is to import necessary libraries and create a dataframe(s). Make note in the form of code comments of what your thought process is as you work on this setup task.

# %%
#import needed libraires with aliases
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

anime_df = pd.read_csv("anime.csv")
manga_df = pd.read_csv("manga.csv")

# Want to see if the dataframe was properly imported and see what kind of data is stored in each column.
anime_df.info()
manga_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24165 entries, 0 to 24164
# Data columns (total 39 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   anime_id          24165 non-null  int64
#  1   title             24165 non-null  object
#  2   type              24092 non-null  object
#  3   score             14272 non-null  float64
#  4   scored_by         24165 non-null  int64
#  5   status            24165 non-null  object
#  6   episodes          23397 non-null  float64
#  7   start_date        21391 non-null  object
#  8   end_date          19912 non-null  object
#  9   source            20404 non-null  object
#  10  members           24165 non-null  int64
#  11  favorites         24165 non-null  int64
#  12  episode_duration  23302 non-null  object
#  13  total_duration    23002 non-null  object
#  14  rating            23148 non-null  object
#  15  sfw               24165 non-null  bool
# ...

# %%
anime_df.head()
# Out:
#    anime_id                               title   type  score  scored_by  \
# 0      5114    Fullmetal Alchemist: Brotherhood     tv   9.13    1871705
# 1     11061              Hunter x Hunter (2011)     tv   9.04    1509622
# 2     38524  Shingeki no Kyojin Season 3 Part 2     tv   9.07    1329500
# 3      9253                         Steins;Gate     tv   9.08    1252286
# 4     28851                      Koe no Katachi  movie   8.95    1398608
#
#             status  episodes  start_date    end_date        source  ...  \
# 0  finished_airing      64.0  2009-04-05  2010-07-04         manga  ...
# 1  finished_airing     148.0  2011-10-02  2014-09-24         manga  ...
# 2  finished_airing      10.0  2019-04-29  2019-07-01         manga  ...
# 3  finished_airing      24.0  2011-04-06  2011-09-14  visual_novel  ...
# 4  finished_airing       1.0  2016-09-17  2016-09-17         manga  ...
#
#                                            producers  \
# ...

# %%
manga_df.head()
# Out:
#    manga_id                                            title   type  score  \
# 0         2                                          Berserk  manga   9.45
# 1        13                                        One Piece  manga   9.20
# 2        25                              Fullmetal Alchemist  manga   9.05
# 3      1706  JoJo no Kimyou na Bouken Part 7: Steel Ball Run  manga   9.27
# 4      4632                                   Oyasumi Punpun  manga   9.03
#
#    scored_by                status  volumes  chapters  start_date    end_date  \
# 0     268737  currently_publishing      NaN       NaN  1989-08-25         NaN
# 1     305917  currently_publishing      NaN       NaN  1997-07-22         NaN
# 2     143879              finished     27.0     116.0  2001-07-12  2010-09-11
# 3     125482              finished     24.0      96.0  2004-01-19  2011-04-19
# 4     141146              finished     13.0     147.0  2007-03-15  2013-11-02
#
# ...

# %% [markdown]
# ## Get to Know the Numbers
#
# Now that you have everything setup, put any code that you use to get to know the dataframe and its rows and columns better in the cell below. You can use whatever techniques you like, except for visualizations. You will put those in a separate section.
#
# When working on your code, make sure to leave comments so that your mentors can understand your thought process.

# %% [markdown]
# <h1 style="background-color:Blue; color:White; text-align:center">Anime CSV Info</h1>

# %%
anime_df.describe()
# Out:
#            anime_id         score     scored_by      episodes       members  \
# count  24165.000000  14272.000000  2.416500e+04  23397.000000  2.416500e+04
# mean   28614.263977      6.459909  1.761367e+04     16.438731  3.422768e+04
# std    17243.874870      0.898645  8.795290e+04     52.256746  1.457479e+05
# min        1.000000      1.850000  0.000000e+00      1.000000  0.000000e+00
# 25%    10075.000000      5.850000  2.300000e+01      1.000000  1.450000e+02
# 50%    33871.000000      6.470000  2.380000e+02      2.000000  8.940000e+02
# 75%    44074.000000      7.110000  3.075000e+03     13.000000  8.488000e+03
# max    52477.000000      9.140000  2.484450e+06   3057.000000  3.473484e+06
#
#            favorites    start_year
# count   24165.000000  17749.000000
# mean      402.318601   2007.543918
# std      4088.882637     13.487168
# min         0.000000   1917.000000
# 25%         0.000000   2002.000000
# 50%         1.000000   2012.000000
# ...

# %%
anime_df.isnull().sum()
# Out:
# anime_id                0
# title                   0
# type                   73
# score                9893
# scored_by               0
# status                  0
# episodes              768
# start_date           2774
# end_date             4253
# source               3761
# members                 0
# favorites               0
# episode_duration      863
# total_duration       1163
# rating               1017
# sfw                     0
# approved                0
# created_at              0
# updated_at              0
# start_year           6416
# start_season         6416
# real_start_date      2774
# real_end_date        4253
# broadcast_day       21100
# broadcast_time      21237
# genres                  0
# themes                  0
# demographics            0
# studios                 0
# producers               0
# licensors               0
# synopsis             3317
# background          21823
# main_picture         2787
# url                     0
# ...

# %%
anime_df.nlargest(10, "episodes")
# Out:
#        anime_id                                  title type  score  scored_by  \
# 14764      9947                                Lan Mao   tv    NaN        174
# 24115     52400                           Martial Peak  NaN    NaN          0
# 11966     12393                             Oyako Club   tv   5.54        381
# 1142       2471                        Doraemon (1979)   tv   7.76      32873
# 12464     23349                 Kirin Monoshiri Yakata   tv   5.62        235
# 10372      6277     Manga Nippon Mukashibanashi (1976)   tv   6.08        409
# 11862      8213                       Hoka Hoka Kazoku   tv   5.81        245
# 12470     32448               Kirin Ashita no Calendar   tv   5.86        160
# 12708     22221  Monoshiri Daigaku: Ashita no Calendar   tv   5.71        179
# 24121     52408        Manga Meisaku Gekijou Sazae-san   tv    NaN          0
#
#                 status  episodes  start_date    end_date    source  ...  \
# ...

# %% [markdown]
# <h1 style="background-color:Purple; color:White; text-align:center">Manga CSV Info</h1>

# %%
manga_df.describe()
# Out:
#             manga_id         score      scored_by       volumes      chapters  \
# count   67273.000000  21910.000000   67273.000000  50494.000000  47095.000000
# mean    77959.681477      6.967913     582.226763      2.888719     20.655144
# std     47358.181042      0.515890    4775.525577      4.810232     62.487535
# min         1.000000      2.450000       0.000000      1.000000      1.000000
# 25%     28581.000000      6.640000       4.000000      1.000000      5.000000
# 50%     87804.000000      6.940000      25.000000      1.000000      9.000000
# 75%    118104.000000      7.260000     195.000000      3.000000     18.000000
# max    149667.000000      9.450000  363368.000000    200.000000   6477.000000
#
#              members      favorites
# count   67273.000000   67273.000000
# mean     1464.975042      47.583399
# std      9613.747178     924.716631
# min         0.000000       0.000000
# 25%        40.000000       0.000000
# 50%       125.000000       0.000000
# ...

# %%
manga_df.isnull().sum()
# Out:
# manga_id                 0
# title                    0
# type                     0
# score                45363
# scored_by                0
# status                   0
# volumes              16779
# chapters             20178
# start_date            4324
# end_date             15552
# members                  0
# favorites                0
# sfw                      0
# approved                 0
# created_at_before        0
# updated_at            8282
# real_start_date       4324
# real_end_date        15552
# genres                   0
# themes                   0
# demographics             0
# authors                  0
# serializations           0
# synopsis             21653
# background           57934
# main_picture          2441
# url                      0
# title_english        48846
# title_japanese        2680
# title_synonyms           0
# jikan                    0
# dtype: int64

# %% [markdown]
# ## Visualize
#
# Create any visualizations for your EDA here. Make note in the form of code comments of what your thought process is for your visualizations.

# %% [markdown]
# <h1 style="background-color:Blue; color:White; text-align:center">Anime Viz </h1>

# %%
anime_df.hist('score')
plt.show()

# %%
anime_df.hist('episodes')
plt.show()

# %%
sns.scatterplot(data= anime_df, x='score', y='episodes')
# Out:
# <AxesSubplot:xlabel='score', ylabel='episodes'>

# %%
anime_df['sfw'].value_counts().plot(kind='bar');

# %% [markdown]
# <h1 style="background-color:Purple; color:White; text-align:center">Manga Viz </h1>

# %%
sns.scatterplot(data=manga_df, x='score', y='volumes')
# Out:
# <AxesSubplot:xlabel='score', ylabel='volumes'>

# %%
manga_df.hist('score')
plt.show()

# %%
manga_df['sfw'].value_counts().plot(kind='bar');

# %% [markdown]
# ## Summarize Your Results
#
# With your EDA complete, answer the following questions.
#
# 1. Was there anything surprising about your dataset?
# 2. Do you have any concerns about your dataset?
# 3. Is there anything you want to make note of for the next phase of your analysis, which is cleaning data?
